# %% [markdown]
# def developer( desarrollador : str ): Cantidad de items y porcentaje de contenido Free por año según empresa desarrolladora. Ejemplo de salida:

# %%
import pandas as pd
import numpy as np

# %%
# Leer dataframe con columnas necesarias
columns = ['id', 'price', 'developer','title', 'release_date']
games = pd.read_csv('steam_games.csv', usecols=columns).rename(columns={'id':'item_id'})
games.sample(10)
# Out:
#                                                    title release_date  price  \
# 11125  Fantasy Grounds - Ultimate Bestiary: Revenge o...   2017-08-23  14.99
# 13259                    Horse Paradise - My Dream Ranch   2017-09-09   9.99
# 6507   Inuyasha the Movie 2: The Castle Beyond the Lo...   2002-12-21   3.99
# 6001                       Falling Stars: War of Empires   2016-04-27  19.99
# 25245         Robotpencil Presents: Approachable Anatomy   2015-10-21   5.99
# 11563                                     FEMINAZI: 3000   2017-09-19   0.99
# 18932                                      Village Story   2017-02-27   1.99
# 29479  Europa Universalis IV: Native Americans II Uni...   2014-02-25   1.99
# 5511                                     Space Overlords   2016-03-03   7.99
# 20244                                                NaN          NaN   5.99
#
#         item_id                   developer
# 11125  697620.0         SmiteWorks USA, LLC
# 13259  764240.0                 Foxie Games
# 6507   488380.0                         NaN
# 6001   439960.0               Riveted Games
# 25245  406260.0                         NaN
# 11563  705070.0            Paradox Terminal
# 18932  601280.0                      DGames
# 29479  278710.0  Paradox Development Studio
# 5511   407830.0                12 Hit Combo
# 20244  425990.0                         NaN
